# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import simulation as sim

import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

# %%
np.random.seed(42)
norm_data = sim.generate_normal_data()
sim.plot_histogram(norm_data)

# %%
data = norm_data


fig, axes = plt.subplots(1, 2, figsize=(20, 10))

AIC_norm, BIC_norm, params = sim.fit_norm(data)
sim.plot_norm(data, **params , ax=axes[0])

AIC_t, BIC_t, params_t = sim.fit_t(data)
sim.plot_t(data, **params_t, ax=axes[1])

fig, axes = plt.subplots(1, 3, figsize=(30, 10))

AIC_gmm2, BIC_gmm2, gmm2 = sim.fit_gmm(data, n_components=2)
sim.plot_gmm(data, gmm2, n_components=2, ax=axes[0])

AIC_gmm3, BIC_gmm3, gmm3 = sim.fit_gmm(data, n_components=3)
sim.plot_gmm(data, gmm3, n_components=3, ax=axes[1])

AIC_gmm4, BIC_gmm4, gmm4 = sim.fit_gmm(data, n_components=4)
sim.plot_gmm(data, gmm4, n_components=4, ax=axes[2])

print(f"Normal: AIC = {AIC_norm}, BIC = {BIC_norm}, params = {params}")
print(f"Student's T: AIC = {AIC_t}, BIC = {BIC_t}, params = {params_t}")
print(f"GMM_2: AIC = {AIC_gmm2}, BIC = {BIC_gmm2}")
print(gmm2.means_,"\n",gmm2.covariances_,"\n",gmm2.weights_)
print()
print(f"GMM_3: AIC = {AIC_gmm3}, BIC = {BIC_gmm3}")
print(gmm3.means_ ,"\n",gmm3.covariances_,"\n",gmm3.weights_)
print()
print(f"GMM_4: AIC = {AIC_gmm4}, BIC = {BIC_gmm4}")
print(gmm4.means_ ,"\n",gmm4.covariances_,"\n",gmm4.weights_)
# Out:
# Normal: AIC = 6017.746209702443, BIC = 6027.561720260407, params = {'mu': np.float64(25.096660279111628), 'std': np.float64(4.893631038736771)}
# Student's T: AIC = 6019.587786022322, BIC = 6034.311051859268, params = {'df': np.float64(102.00866912485566), 'loc': np.float64(25.09134034315934), 'scale': np.float64(4.845392933534033)}
# GMM_2: AIC = 6027.329671287753, BIC = 6051.868447682664
# [[28.00010374]
#  [22.12193467]]
#  [[[16.5393282 ]]
#
#  [[14.05186355]]]
#  [0.5060633 0.4939367]
#
# GMM_3: AIC = 6033.590940847864, BIC = 6072.852983079721
# [[31.53605601]
#  [20.78454822]
#  [26.15697133]]
#  [[[10.41916338]]
#
#  [[10.19255739]]
#
#  [[ 5.96874051]]]
#  [0.18903271 0.3866289  0.42433839]
#
# GMM_4: AIC = 6039.03843536537, BIC = 6093.023743434173
# [[32.00650516]
#  [22.64891238]
#  [27.03983698]
#  [18.48104057]]
#  [[[9.03158158]]
#
#  [[3.51652418]]
#
#  [[3.57061582]]
#
#  [[7.23311458]]]
#  [0.17212277 0.30534031 0.35226448 0.17027243]

# %%
np.random.seed(42)
connorm_data = sim.generate_contaminated_normal(lambda_=4)
sim.plot_histogram(connorm_data)

# %%
data = connorm_data

fig, axes = plt.subplots(1, 2, figsize=(20, 10))

AIC_norm, BIC_norm, params = sim.fit_norm(data)
sim.plot_norm(data, **params , ax=axes[0])

AIC_t, BIC_t, params_t = sim.fit_t(data)
sim.plot_t(data, **params_t, ax=axes[1])

fig, axes = plt.subplots(1, 3, figsize=(30, 10))

AIC_gmm2, BIC_gmm2, gmm2 = sim.fit_gmm(data, n_components=2)
sim.plot_gmm(data, gmm2, n_components=2, ax=axes[0])

AIC_gmm3, BIC_gmm3, gmm3 = sim.fit_gmm(data, n_components=3)
sim.plot_gmm(data, gmm3, n_components=3, ax=axes[1])

AIC_gmm4, BIC_gmm4, gmm4 = sim.fit_gmm(data, n_components=4)
sim.plot_gmm(data, gmm4, n_components=4, ax=axes[2])

print(f"Normal: AIC = {AIC_norm}, BIC = {BIC_norm}, params = {params}")
print(f"Student's T: AIC = {AIC_t}, BIC = {BIC_t}, params = {params_t}")
print(f"GMM_2: AIC = {AIC_gmm2}, BIC = {BIC_gmm2}")
print(gmm2.means_,"\n",gmm2.covariances_,"\n",gmm2.weights_)
print()
print(f"GMM_3: AIC = {AIC_gmm3}, BIC = {BIC_gmm3}")
print(gmm3.means_ ,"\n",gmm3.covariances_,"\n",gmm3.weights_)
print()
print(f"GMM_4: AIC = {AIC_gmm4}, BIC = {BIC_gmm4}")
print(gmm4.means_ ,"\n",gmm4.covariances_,"\n",gmm4.weights_)
# Out:
# Normal: AIC = 7408.288816765947, BIC = 7418.104327323911, params = {'mu': np.float64(25.01975152810746), 'std': np.float64(9.808073520890993)}
# Student's T: AIC = 7064.7763213357, BIC = 7079.499587172647, params = {'df': np.float64(1.8462051038667173), 'loc': np.float64(24.920694095262604), 'scale': np.float64(4.904372251521167)}
# GMM_2: AIC = 7037.4507165777295, BIC = 7061.989492972641
# [[23.02713149]
#  [25.47946684]]
#  [[[392.16265124]]
#
#  [[ 26.78930326]]]
#  [0.18746021 0.81253979]
#
# GMM_3: AIC = 7043.886800389548, BIC = 7083.148842621405
# [[ 5.77229581]
#  [30.87005676]
#  [25.40464317]]
#  [[[154.36913358]]
#
#  [[238.88677981]]
#
#  [[ 24.05379251]]]
#  [0.06418764 0.16014567 0.7756667 ]
#
# GMM_4: AIC = 7053.289395152612, BIC = 7107.274703221416
# [[ 6.64772321]
#  [29.24422052]
#  [22.95681682]
#  [43.38834511]]
#  [[[130.15046126]]
#
#  [[ 18.00744204]]
#
#  [[ 16.01316705]]
#
#  [[175.88744157]]]
#  [0.08922416 0.35908997 0.48999904 0.06168683]

# %%
np.random.seed(42)
cauchy_data = sim.generate_cauchy_data()
sim.plot_histogram(cauchy_data)

# %%
data = cauchy_data


fig, axes = plt.subplots(1, 2, figsize=(15, 10))

AIC_norm, BIC_norm, params = sim.fit_norm(data)
sim.plot_norm(data, **params , ax=axes[0])

AIC_t, BIC_t, params_t = sim.fit_t(data)
sim.plot_t(data, **params_t, ax=axes[1])

fig, axes = plt.subplots(1, 3, figsize=(25, 10))

AIC_gmm2, BIC_gmm2, gmm = sim.fit_gmm(data, n_components=2)
sim.plot_gmm(data, gmm, n_components=2, ax=axes[0])

AIC_gmm3, BIC_gmm3, gmm = sim.fit_gmm(data, n_components=3)
sim.plot_gmm(data, gmm, n_components=3, ax=axes[1])

AIC_gmm4, BIC_gmm4, gmm = sim.fit_gmm(data, n_components=4)
sim.plot_gmm(data, gmm, n_components=4, ax=axes[2])

print(f"Normal: AIC = {AIC_norm}, BIC = {BIC_norm}")
print(f"Student's T: AIC = {AIC_t}, BIC = {BIC_t}")
print(f"GMM_2: AIC = {AIC_gmm2}, BIC = {BIC_gmm2}")
print(f"GMM_3: AIC = {AIC_gmm3}, BIC = {BIC_gmm3}")
print(f"GMM_4: AIC = {AIC_gmm4}, BIC = {BIC_gmm4}")
# Out:
# Normal: AIC = 9426.200412616545, BIC = 9436.003887029858
# Student's T: AIC = 8136.621078481909, BIC = 8151.326290101878
# GMM_2: AIC = 8216.746806210705, BIC = 8241.255492243989
# GMM_3: AIC = 8221.983472018295, BIC = 8261.197369671549
# GMM_4: AIC = 8161.952386575999, BIC = 8215.871495849222

# %%
levy_data = sim.generate_levy(beta=0.8, location=25,scale=10)
sim.plot_histogram(levy_data, bins=100)

# %%
data = levy_data


fig, axes = plt.subplots(1, 2, figsize=(20, 10))

AIC_norm, BIC_norm, params = sim.fit_norm(data)
sim.plot_norm(data, **params , ax=axes[0])

AIC_t, BIC_t, params_t = sim.fit_t(data)
sim.plot_t(data, **params_t, ax=axes[1])

fig, axes = plt.subplots(1, 3, figsize=(30, 10))

AIC_gmm2, BIC_gmm2, gmm2 = sim.fit_gmm(data, n_components=2)
sim.plot_gmm(data, gmm2, n_components=2, ax=axes[0])

AIC_gmm3, BIC_gmm3, gmm3 = sim.fit_gmm(data, n_components=3)
sim.plot_gmm(data, gmm3, n_components=3, ax=axes[1])

AIC_gmm4, BIC_gmm4, gmm4 = sim.fit_gmm(data, n_components=4)
sim.plot_gmm(data, gmm4, n_components=4, ax=axes[2])

print(f"Normal: AIC = {AIC_norm}, BIC = {BIC_norm}, params = {params}")
print(f"Student's T: AIC = {AIC_t}, BIC = {BIC_t}, params = {params_t}")
print(f"GMM_2: AIC = {AIC_gmm2}, BIC = {BIC_gmm2}")
print(gmm2.means_,"\n",gmm2.covariances_,"\n",gmm2.weights_)
print()
print(f"GMM_3: AIC = {AIC_gmm3}, BIC = {BIC_gmm3}")
print(gmm3.means_ ,"\n",gmm3.covariances_,"\n",gmm3.weights_)
print()
print(f"GMM_4: AIC = {AIC_gmm4}, BIC = {BIC_gmm4}")
print(gmm4.means_ ,"\n",gmm4.covariances_,"\n",gmm4.weights_)
# Out:
# Normal: AIC = 9161.579806551996, BIC = 9171.393316109294, params = {'mu': np.float64(23.064799585742364), 'std': np.float64(23.675357596428643)}
# Student's T: AIC = 8717.132358231851, BIC = 8731.852622567796, params = {'df': np.float64(2.637844282483408), 'loc': np.float64(18.72574359002073), 'scale': np.float64(12.623090789389263)}
# GMM_2: AIC = 8656.881523318149, BIC = 8681.415297211392
# [[17.8867153 ]
#  [60.46688696]]
#  [[[ 176.08732108]]
#
#  [[1744.76922614]]]
#  [0.87839212 0.12160788]
#
# GMM_3: AIC = 8634.056776056223, BIC = 8673.31081428541
# [[13.45623013]
#  [33.44868362]
#  [73.48926102]]
#  [[[ 112.55351451]]
#
#  [[ 212.79351312]]
#
#  [[2386.80765435]]]
#  [0.65666928 0.2747866  0.06854412]
#
# GMM_4: AIC = 8635.835045841823, BIC = 8689.809348406956
# [[ 7.24735863]
#  [44.91148275]
#  [87.25162173]
#  [22.44134739]]
#  [[[  74.76949882]]
#
#  [[ 304.70680022]]
#
#  [[3278.72149025]]
#
#  [[  80.26889948]]]
#  [0.35854509 0.15973454 0.03829525 0.44342512]

# %%
weibull_data = sim.generate_weibull()
sim.plot_histogram(weibull_data)

# %%
data = weibull_data


fig, axes = plt.subplots(1, 2, figsize=(20, 10))

AIC_norm, BIC_norm, params = sim.fit_norm(data)
sim.plot_norm(data, **params , ax=axes[0])

AIC_t, BIC_t, params_t = sim.fit_t(data)
sim.plot_t(data, **params_t, ax=axes[1])

fig, axes = plt.subplots(1, 3, figsize=(30, 10))

AIC_gmm2, BIC_gmm2, gmm2 = sim.fit_gmm(data, n_components=2)
sim.plot_gmm(data, gmm2, n_components=2, ax=axes[0])

AIC_gmm3, BIC_gmm3, gmm3 = sim.fit_gmm(data, n_components=3)
sim.plot_gmm(data, gmm3, n_components=3, ax=axes[1])

AIC_gmm4, BIC_gmm4, gmm4 = sim.fit_gmm(data, n_components=4)
sim.plot_gmm(data, gmm4, n_components=4, ax=axes[2])

print(f"Normal: AIC = {AIC_norm}, BIC = {BIC_norm}, params = {params}")
print(f"Student's T: AIC = {AIC_t}, BIC = {BIC_t}, params = {params_t}")
print(f"GMM_2: AIC = {AIC_gmm2}, BIC = {BIC_gmm2}")
print(gmm2.means_,"\n",gmm2.covariances_,"\n",gmm2.weights_)
print()
print(f"GMM_3: AIC = {AIC_gmm3}, BIC = {BIC_gmm3}")
print(gmm3.means_ ,"\n",gmm3.covariances_,"\n",gmm3.weights_)
print()
print(f"GMM_4: AIC = {AIC_gmm4}, BIC = {BIC_gmm4}")
print(gmm4.means_ ,"\n",gmm4.covariances_,"\n",gmm4.weights_)
# Out:
# Normal: AIC = 8249.010354850618, BIC = 8258.825865408582, params = {'mu': np.float64(21.983439970747884), 'std': np.float64(14.932897188821743)}
# Student's T: AIC = 8212.022883635655, BIC = 8226.746149472601, params = {'df': np.float64(7.546297148790197), 'loc': np.float64(20.586016570541247), 'scale': np.float64(12.776175602190843)}
# GMM_2: AIC = 8075.421108633579, BIC = 8099.95988502849
# [[34.77000735]
#  [13.95037458]]
#  [[[216.87390028]]
#
#  [[ 59.58923371]]]
#  [0.38584088 0.61415912]
#
# GMM_3: AIC = 8026.761260288314, BIC = 8066.023302520171
# [[45.66836888]
#  [10.63337202]
#  [27.05739389]]
#  [[[217.60244263]]
#
#  [[ 30.60602223]]
#
#  [[ 58.77659617]]]
#  [0.14805765 0.4767073  0.37523504]
#
# GMM_4: AIC = 8019.253197153255, BIC = 8073.238505222059
# [[35.8232557 ]
#  [ 9.11555735]
#  [21.73243206]
#  [51.82710678]]
#  [[[ 43.13891683]]
#
#  [[ 21.39860275]]
#
#  [[ 29.12099494]]
#
#  [[209.50897305]]]
#  [0.18755923 0.39615552 0.32967894 0.0866063 ]
